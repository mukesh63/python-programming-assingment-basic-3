# %% [markdown]
#  # Q1

# %%
num = int(input('enter a number: '))
if num > 0:
    print('it is positive')
elif num == 0:
    print('it is zero')
elif num < 0:
    print('it is negative')
else:
    pass
# Out:
# enter a number: -4
# it is negative

# %% [markdown]
# # Q2

# %%
a = int(input('Enter a value: '))
if a%2 == 0:
    print('it is even')
else:
    print('it is odd')
# Out:
# Enter a value: 4
# it is even

# %% [markdown]
# # Q3

# %%
year = int(input('enter a year: '))
if year%4 == 0:
    pass
elif year % 100 == 0:
    pass
elif year % 400 == 0:
    pass
else:
    print('it is not a leap year')
# Out:
# enter a year: 2021
# it is not a leap year

# %% [markdown]
# # Q4

# %%
prime = int(input('Enter a number: '))
if prime > 1:
    if prime % 2 == 0:
        print('it is a prime number: ',prime)
    else:
        print('it is not a prime number')
# Out:
# Enter a number: 5
# it is not a prime number

# %% [markdown]
# # Q5

# %%
n = int(input('enter the number: '))
if n > 1:
    for i in range(2,n):
        if i % 2 == 0:
            print('the prime numbers are: ',i)
        else:
            pass
# Out:
# enter the number10000
# the prime numbers are:  2
# the prime numbers are:  4
# the prime numbers are:  6
# the prime numbers are:  8
# the prime numbers are:  10
# the prime numbers are:  12
# the prime numbers are:  14
# the prime numbers are:  16
# the prime numbers are:  18
# the prime numbers are:  20
# the prime numbers are:  22
# the prime numbers are:  24
# the prime numbers are:  26
# the prime numbers are:  28
# the prime numbers are:  30
# the prime numbers are:  32
# the prime numbers are:  34
# the prime numbers are:  36
# the prime numbers are:  38
# the prime numbers are:  40
# the prime numbers are:  42
# the prime numbers are:  44
# the prime numbers are:  46
# the prime numbers are:  48
# the prime numbers are:  50
# the prime numbers are:  52
# the prime numbers are:  54
# the prime numbers are:  56
# the prime numbers are:  58
# the prime numbers are:  60
# the prime numbers are:  62
# the prime numbers are:  64
# the prime numbers are:  66
# the prime numbers are:  68
# the prime numbers are:  70
# the prime numbers are:  72
# the prime numbers are:  74
# the prime numbers are:  76
# the prime numbers are:  78
# the prime numbers are:  80
# the prime numbers are:  82
# the prime numbers are:  84
# the prime numbers are:  86
# the prime numbers are:  88
# the prime numbers are:  90
# the prime numbers are:  92
# the prime numbers are:  94
# the prime numbers are:  96
# the prime numbers are:  98
# the prime numbers are:  100
# the prime numbers are:  102
# the prime numbers are:  104
# the prime numbers are:  106
# the prime numbers are:  108
# the prime numbers are:  110
# the prime numbers are:  112
# the prime numbers are:  114
# the prime numbers are:  116
# the prime numbers are:  118
# the prime numbers are:  120
# the prime numbers are:  122
# the prime numbers are:  124
# the prime numbers are:  126
# the prime numbers are:  128
# the prime numbers are:  130
# the prime numbers are:  132
# the prime numbers are:  134
# the prime numbers are:  136
# the prime numbers are:  138
# the prime numbers are:  140
# the prime numbers are:  142
# the prime numbers are:  144
# the prime numbers are:  146
# the prime numbers are:  148
# the prime numbers are:  150
# the prime numbers are:  152
# the prime numbers are:  154
# the prime numbers are:  156
# the prime numbers are:  158
# the prime numbers are:  160
# the prime numbers are:  162
# the prime numbers are:  164
# the prime numbers are:  166
# the prime numbers are:  168
# the prime numbers are:  170
# the prime numbers are:  172
# the prime numbers are:  174
# the prime numbers are:  176
# the prime numbers are:  178
# the prime numbers are:  180
# the prime numbers are:  182
# the prime numbers are:  184
# the prime numbers are:  186
# the prime numbers are:  188
# the prime numbers are:  190
# the prime numbers are:  192
# the prime numbers are:  194
# the prime numbers are:  196
# the prime numbers are:  198
# the prime numbers are:  200
# the prime numbers are:  202
# the prime numbers are:  204
# the prime numbers are:  206
# the prime numbers are:  208
# the prime numbers are:  210
# the prime numbers are:  212
# the prime numbers are:  214
# the prime numbers are:  216
# the prime numbers are:  218
# the prime numbers are:  220
# the prime numbers are:  222
# the prime numbers are:  224
# the prime numbers are:  226
# the prime numbers are:  228
# the prime numbers are:  230
# the prime numbers are:  232
# the prime numbers are:  234
# the prime numbers are:  236
# the prime numbers are:  238
# the prime numbers are:  240
# the prime numbers are:  242
# the prime numbers are:  244
# the prime numbers are:  246
# the prime numbers are:  248
# the prime numbers are:  250
# the prime numbers are:  252
# the prime numbers are:  254
# the prime numbers are:  256
# the prime numbers are:  258
# the prime numbers are:  260
# the prime numbers are:  262
# the prime numbers are:  264
# the prime numbers are:  266
# the prime numbers are:  268
# the prime numbers are:  270
# the prime numbers are:  272
# the prime numbers are:  274
# the prime numbers are:  276
# the prime numbers are:  278
# the prime numbers are:  280
# the prime numbers are:  282
# the prime numbers are:  284
# the prime numbers are:  286
# the prime numbers are:  288
# the prime numbers are:  290
# the prime numbers are:  292
# the prime numbers are:  294
# the prime numbers are:  296
# the prime numbers are:  298
# the prime numbers are:  300
# the prime numbers are:  302
# the prime numbers are:  304
# the prime numbers are:  306
# the prime numbers are:  308
# the prime numbers are:  310
# the prime numbers are:  312
# the prime numbers are:  314
# the prime numbers are:  316
# the prime numbers are:  318
# the prime numbers are:  320
# the prime numbers are:  322
# the prime numbers are:  324
# the prime numbers are:  326
# the prime numbers are:  328
# the prime numbers are:  330
# the prime numbers are:  332
# the prime numbers are:  334
# the prime numbers are:  336
# the prime numbers are:  338
# the prime numbers are:  340
# the prime numbers are:  342
# the prime numbers are:  344
# the prime numbers are:  346
# the prime numbers are:  348
# the prime numbers are:  350
# the prime numbers are:  352
# the prime numbers are:  354
# the prime numbers are:  356
# the prime numbers are:  358
# the prime numbers are:  360
# the prime numbers are:  362
# the prime numbers are:  364
# the prime numbers are:  366
# the prime numbers are:  368
# the prime numbers are:  370
# the prime numbers are:  372
# the prime numbers are:  374
# the prime numbers are:  376
# the prime numbers are:  378
# the prime numbers are:  380
# the prime numbers are:  382
# the prime numbers are:  384
# the prime numbers are:  386
# the prime numbers are:  388
# the prime numbers are:  390
# the prime numbers are:  392
# the prime numbers are:  394
# the prime numbers are:  396
# the prime numbers are:  398
# the prime numbers are:  400
# the prime numbers are:  402
# the prime numbers are:  404
# the prime numbers are:  406
# the prime numbers are:  408
# the prime numbers are:  410
# the prime numbers are:  412
# the prime numbers are:  414
# the prime numbers are:  416
# the prime numbers are:  418
# the prime numbers are:  420
# the prime numbers are:  422
# the prime numbers are:  424
# the prime numbers are:  426
# the prime numbers are:  428
# the prime numbers are:  430
# the prime numbers are:  432
# the prime numbers are:  434
# the prime numbers are:  436
# the prime numbers are:  438
# the prime numbers are:  440
# the prime numbers are:  442
# the prime numbers are:  444
# the prime numbers are:  446
# the prime numbers are:  448
# the prime numbers are:  450
# the prime numbers are:  452
# the prime numbers are:  454
# the prime numbers are:  456
# the prime numbers are:  458
# the prime numbers are:  460
# the prime numbers are:  462
# the prime numbers are:  464
# the prime numbers are:  466
# the prime numbers are:  468
# the prime numbers are:  470
# the prime numbers are:  472
# the prime numbers are:  474
# the prime numbers are:  476
# the prime numbers are:  478
# the prime numbers are:  480
# the prime numbers are:  482
# the prime numbers are:  484
# the prime numbers are:  486
# the prime numbers are:  488
# the prime numbers are:  490
# the prime numbers are:  492
# the prime numbers are:  494
# the prime numbers are:  496
# the prime numbers are:  498
# the prime numbers are:  500
# the prime numbers are:  502
# the prime numbers are:  504
# the prime numbers are:  506
# the prime numbers are:  508
# the prime numbers are:  510
# the prime numbers are:  512
# the prime numbers are:  514
# the prime numbers are:  516
# the prime numbers are:  518
# the prime numbers are:  520
# the prime numbers are:  522
# the prime numbers are:  524
# the prime numbers are:  526
# the prime numbers are:  528
# the prime numbers are:  530
# the prime numbers are:  532
# the prime numbers are:  534
# the prime numbers are:  536
# the prime numbers are:  538
# the prime numbers are:  540
# the prime numbers are:  542
# the prime numbers are:  544
# the prime numbers are:  546
# the prime numbers are:  548
# the prime numbers are:  550
# the prime numbers are:  552
# the prime numbers are:  554
# the prime numbers are:  556
# the prime numbers are:  558
# the prime numbers are:  560
# the prime numbers are:  562
# the prime numbers are:  564
# the prime numbers are:  566
# the prime numbers are:  568
# the prime numbers are:  570
# the prime numbers are:  572
# the prime numbers are:  574
# the prime numbers are:  576
# the prime numbers are:  578
# the prime numbers are:  580
# the prime numbers are:  582
# the prime numbers are:  584
# the prime numbers are:  586
# the prime numbers are:  588
# the prime numbers are:  590
# the prime numbers are:  592
# the prime numbers are:  594
# the prime numbers are:  596
# the prime numbers are:  598
# the prime numbers are:  600
# the prime numbers are:  602
# the prime numbers are:  604
# the prime numbers are:  606
# the prime numbers are:  608
# the prime numbers are:  610
# the prime numbers are:  612
# the prime numbers are:  614
# the prime numbers are:  616
# the prime numbers are:  618
# the prime numbers are:  620
# the prime numbers are:  622
# the prime numbers are:  624
# the prime numbers are:  626
# the prime numbers are:  628
# the prime numbers are:  630
# the prime numbers are:  632
# the prime numbers are:  634
# the prime numbers are:  636
# the prime numbers are:  638
# the prime numbers are:  640
# the prime numbers are:  642
# the prime numbers are:  644
# the prime numbers are:  646
# the prime numbers are:  648
# the prime numbers are:  650
# the prime numbers are:  652
# the prime numbers are:  654
# the prime numbers are:  656
# the prime numbers are:  658
# the prime numbers are:  660
# the prime numbers are:  662
# the prime numbers are:  664
# the prime numbers are:  666
# the prime numbers are:  668
# the prime numbers are:  670
# the prime numbers are:  672
# the prime numbers are:  674
# the prime numbers are:  676
# the prime numbers are:  678
# the prime numbers are:  680
# the prime numbers are:  682
# the prime numbers are:  684
# the prime numbers are:  686
# the prime numbers are:  688
# the prime numbers are:  690
# the prime numbers are:  692
# the prime numbers are:  694
# the prime numbers are:  696
# the prime numbers are:  698
# the prime numbers are:  700
# the prime numbers are:  702
# the prime numbers are:  704
# the prime numbers are:  706
# the prime numbers are:  708
# the prime numbers are:  710
# the prime numbers are:  712
# the prime numbers are:  714
# the prime numbers are:  716
# the prime numbers are:  718
# the prime numbers are:  720
# the prime numbers are:  722
# the prime numbers are:  724
# the prime numbers are:  726
# the prime numbers are:  728
# the prime numbers are:  730
# the prime numbers are:  732
# the prime numbers are:  734
# the prime numbers are:  736
# the prime numbers are:  738
# the prime numbers are:  740
# the prime numbers are:  742
# the prime numbers are:  744
# the prime numbers are:  746
# the prime numbers are:  748
# the prime numbers are:  750
# the prime numbers are:  752
# the prime numbers are:  754
# the prime numbers are:  756
# the prime numbers are:  758
# the prime numbers are:  760
# the prime numbers are:  762
# the prime numbers are:  764
# the prime numbers are:  766
# the prime numbers are:  768
# the prime numbers are:  770
# the prime numbers are:  772
# the prime numbers are:  774
# the prime numbers are:  776
# the prime numbers are:  778
# the prime numbers are:  780
# the prime numbers are:  782
# the prime numbers are:  784
# the prime numbers are:  786
# the prime numbers are:  788
# the prime numbers are:  790
# the prime numbers are:  792
# the prime numbers are:  794
# the prime numbers are:  796
# the prime numbers are:  798
# the prime numbers are:  800
# the prime numbers are:  802
# the prime numbers are:  804
# the prime numbers are:  806
# the prime numbers are:  808
# the prime numbers are:  810
# the prime numbers are:  812
# the prime numbers are:  814
# the prime numbers are:  816
# the prime numbers are:  818
# the prime numbers are:  820
# the prime numbers are:  822
# the prime numbers are:  824
# the prime numbers are:  826
# the prime numbers are:  828
# the prime numbers are:  830
# the prime numbers are:  832
# the prime numbers are:  834
# the prime numbers are:  836
# the prime numbers are:  838
# the prime numbers are:  840
# the prime numbers are:  842
# the prime numbers are:  844
# the prime numbers are:  846
# the prime numbers are:  848
# the prime numbers are:  850
# the prime numbers are:  852
# the prime numbers are:  854
# the prime numbers are:  856
# the prime numbers are:  858
# the prime numbers are:  860
# the prime numbers are:  862
# the prime numbers are:  864
# the prime numbers are:  866
# the prime numbers are:  868
# the prime numbers are:  870
# the prime numbers are:  872
# the prime numbers are:  874
# the prime numbers are:  876
# the prime numbers are:  878
# the prime numbers are:  880
# the prime numbers are:  882
# the prime numbers are:  884
# the prime numbers are:  886
# the prime numbers are:  888
# the prime numbers are:  890
# the prime numbers are:  892
# the prime numbers are:  894
# the prime numbers are:  896
# the prime numbers are:  898
# the prime numbers are:  900
# the prime numbers are:  902
# the prime numbers are:  904
# the prime numbers are:  906
# the prime numbers are:  908
# the prime numbers are:  910
# the prime numbers are:  912
# the prime numbers are:  914
# the prime numbers are:  916
# the prime numbers are:  918
# the prime numbers are:  920
# the prime numbers are:  922
# the prime numbers are:  924
# the prime numbers are:  926
# the prime numbers are:  928
# the prime numbers are:  930
# the prime numbers are:  932
# the prime numbers are:  934
# the prime numbers are:  936
# the prime numbers are:  938
# the prime numbers are:  940
# the prime numbers are:  942
# the prime numbers are:  944
# the prime numbers are:  946
# the prime numbers are:  948
# the prime numbers are:  950
# the prime numbers are:  952
# the prime numbers are:  954
# the prime numbers are:  956
# the prime numbers are:  958
# the prime numbers are:  960
# the prime numbers are:  962
# the prime numbers are:  964
# the prime numbers are:  966
# the prime numbers are:  968
# the prime numbers are:  970
# the prime numbers are:  972
# the prime numbers are:  974
# the prime numbers are:  976
# the prime numbers are:  978
# the prime numbers are:  980
# the prime numbers are:  982
# the prime numbers are:  984
# the prime numbers are:  986
# the prime numbers are:  988
# the prime numbers are:  990
# the prime numbers are:  992
# the prime numbers are:  994
# the prime numbers are:  996
# the prime numbers are:  998
# the prime numbers are:  1000
# the prime numbers are:  1002
# the prime numbers are:  1004
# the prime numbers are:  1006
# the prime numbers are:  1008
# the prime numbers are:  1010
# the prime numbers are:  1012
# the prime numbers are:  1014
# the prime numbers are:  1016
# the prime numbers are:  1018
# the prime numbers are:  1020
# the prime numbers are:  1022
# the prime numbers are:  1024
# the prime numbers are:  1026
# the prime numbers are:  1028
# the prime numbers are:  1030
# the prime numbers are:  1032
# the prime numbers are:  1034
# the prime numbers are:  1036
# the prime numbers are:  1038
# the prime numbers are:  1040
# the prime numbers are:  1042
# the prime numbers are:  1044
# the prime numbers are:  1046
# the prime numbers are:  1048
# the prime numbers are:  1050
# the prime numbers are:  1052
# the prime numbers are:  1054
# the prime numbers are:  1056
# the prime numbers are:  1058
# the prime numbers are:  1060
# the prime numbers are:  1062
# the prime numbers are:  1064
# the prime numbers are:  1066
# the prime numbers are:  1068
# the prime numbers are:  1070
# the prime numbers are:  1072
# the prime numbers are:  1074
# the prime numbers are:  1076
# the prime numbers are:  1078
# the prime numbers are:  1080
# the prime numbers are:  1082
# the prime numbers are:  1084
# the prime numbers are:  1086
# the prime numbers are:  1088
# the prime numbers are:  1090
# the prime numbers are:  1092
# the prime numbers are:  1094
# the prime numbers are:  1096
# the prime numbers are:  1098
# the prime numbers are:  1100
# the prime numbers are:  1102
# the prime numbers are:  1104
# the prime numbers are:  1106
# the prime numbers are:  1108
# the prime numbers are:  1110
# the prime numbers are:  1112
# the prime numbers are:  1114
# the prime numbers are:  1116
# the prime numbers are:  1118
# the prime numbers are:  1120
# the prime numbers are:  1122
# the prime numbers are:  1124
# the prime numbers are:  1126
# the prime numbers are:  1128
# the prime numbers are:  1130
# the prime numbers are:  1132
# the prime numbers are:  1134
# the prime numbers are:  1136
# the prime numbers are:  1138
# the prime numbers are:  1140
# the prime numbers are:  1142
# the prime numbers are:  1144
# the prime numbers are:  1146
# the prime numbers are:  1148
# the prime numbers are:  1150
# the prime numbers are:  1152
# the prime numbers are:  1154
# the prime numbers are:  1156
# the prime numbers are:  1158
# the prime numbers are:  1160
# the prime numbers are:  1162
# the prime numbers are:  1164
# the prime numbers are:  1166
# the prime numbers are:  1168
# the prime numbers are:  1170
# the prime numbers are:  1172
# the prime numbers are:  1174
# the prime numbers are:  1176
# the prime numbers are:  1178
# the prime numbers are:  1180
# the prime numbers are:  1182
# the prime numbers are:  1184
# the prime numbers are:  1186
# the prime numbers are:  1188
# the prime numbers are:  1190
# the prime numbers are:  1192
# the prime numbers are:  1194
# the prime numbers are:  1196
# the prime numbers are:  1198
# the prime numbers are:  1200
# the prime numbers are:  1202
# the prime numbers are:  1204
# the prime numbers are:  1206
# the prime numbers are:  1208
# the prime numbers are:  1210
# the prime numbers are:  1212
# the prime numbers are:  1214
# the prime numbers are:  1216
# the prime numbers are:  1218
# the prime numbers are:  1220
# the prime numbers are:  1222
# the prime numbers are:  1224
# the prime numbers are:  1226
# the prime numbers are:  1228
# the prime numbers are:  1230
# the prime numbers are:  1232
# the prime numbers are:  1234
# the prime numbers are:  1236
# the prime numbers are:  1238
# the prime numbers are:  1240
# the prime numbers are:  1242
# the prime numbers are:  1244
# the prime numbers are:  1246
# the prime numbers are:  1248
# the prime numbers are:  1250
# the prime numbers are:  1252
# the prime numbers are:  1254
# the prime numbers are:  1256
# the prime numbers are:  1258
# the prime numbers are:  1260
# the prime numbers are:  1262
# the prime numbers are:  1264
# the prime numbers are:  1266
# the prime numbers are:  1268
# the prime numbers are:  1270
# the prime numbers are:  1272
# the prime numbers are:  1274
# the prime numbers are:  1276
# the prime numbers are:  1278
# the prime numbers are:  1280
# the prime numbers are:  1282
# the prime numbers are:  1284
# the prime numbers are:  1286
# the prime numbers are:  1288
# the prime numbers are:  1290
# the prime numbers are:  1292
# the prime numbers are:  1294
# the prime numbers are:  1296
# the prime numbers are:  1298
# the prime numbers are:  1300
# the prime numbers are:  1302
# the prime numbers are:  1304
# the prime numbers are:  1306
# the prime numbers are:  1308
# the prime numbers are:  1310
# the prime numbers are:  1312
# the prime numbers are:  1314
# the prime numbers are:  1316
# the prime numbers are:  1318
# the prime numbers are:  1320
# the prime numbers are:  1322
# the prime numbers are:  1324
# the prime numbers are:  1326
# the prime numbers are:  1328
# the prime numbers are:  1330
# the prime numbers are:  1332
# the prime numbers are:  1334
# the prime numbers are:  1336
# the prime numbers are:  1338
# the prime numbers are:  1340
# the prime numbers are:  1342
# the prime numbers are:  1344
# the prime numbers are:  1346
# the prime numbers are:  1348
# the prime numbers are:  1350
# the prime numbers are:  1352
# the prime numbers are:  1354
# the prime numbers are:  1356
# the prime numbers are:  1358
# the prime numbers are:  1360
# the prime numbers are:  1362
# the prime numbers are:  1364
# the prime numbers are:  1366
# the prime numbers are:  1368
# the prime numbers are:  1370
# the prime numbers are:  1372
# the prime numbers are:  1374
# the prime numbers are:  1376
# the prime numbers are:  1378
# the prime numbers are:  1380
# the prime numbers are:  1382
# the prime numbers are:  1384
# the prime numbers are:  1386
# the prime numbers are:  1388
# the prime numbers are:  1390
# the prime numbers are:  1392
# the prime numbers are:  1394
# the prime numbers are:  1396
# the prime numbers are:  1398
# the prime numbers are:  1400
# the prime numbers are:  1402
# the prime numbers are:  1404
# the prime numbers are:  1406
# the prime numbers are:  1408
# the prime numbers are:  1410
# the prime numbers are:  1412
# the prime numbers are:  1414
# the prime numbers are:  1416
# the prime numbers are:  1418
# the prime numbers are:  1420
# the prime numbers are:  1422
# the prime numbers are:  1424
# the prime numbers are:  1426
# the prime numbers are:  1428
# the prime numbers are:  1430
# the prime numbers are:  1432
# the prime numbers are:  1434
# the prime numbers are:  1436
# the prime numbers are:  1438
# the prime numbers are:  1440
# the prime numbers are:  1442
# the prime numbers are:  1444
# the prime numbers are:  1446
# the prime numbers are:  1448
# the prime numbers are:  1450
# the prime numbers are:  1452
# the prime numbers are:  1454
# the prime numbers are:  1456
# the prime numbers are:  1458
# the prime numbers are:  1460
# the prime numbers are:  1462
# the prime numbers are:  1464
# the prime numbers are:  1466
# the prime numbers are:  1468
# the prime numbers are:  1470
# the prime numbers are:  1472
# the prime numbers are:  1474
# the prime numbers are:  1476
# the prime numbers are:  1478
# the prime numbers are:  1480
# the prime numbers are:  1482
# the prime numbers are:  1484
# the prime numbers are:  1486
# the prime numbers are:  1488
# the prime numbers are:  1490
# the prime numbers are:  1492
# the prime numbers are:  1494
# the prime numbers are:  1496
# the prime numbers are:  1498
# the prime numbers are:  1500
# the prime numbers are:  1502
# the prime numbers are:  1504
# the prime numbers are:  1506
# the prime numbers are:  1508
# the prime numbers are:  1510
# the prime numbers are:  1512
# the prime numbers are:  1514
# the prime numbers are:  1516
# the prime numbers are:  1518
# the prime numbers are:  1520
# the prime numbers are:  1522
# the prime numbers are:  1524
# the prime numbers are:  1526
# the prime numbers are:  1528
# the prime numbers are:  1530
# the prime numbers are:  1532
# the prime numbers are:  1534
# the prime numbers are:  1536
# the prime numbers are:  1538
# the prime numbers are:  1540
# the prime numbers are:  1542
# the prime numbers are:  1544
# the prime numbers are:  1546
# the prime numbers are:  1548
# the prime numbers are:  1550
# the prime numbers are:  1552
# the prime numbers are:  1554
# the prime numbers are:  1556
# the prime numbers are:  1558
# the prime numbers are:  1560
# the prime numbers are:  1562
# the prime numbers are:  1564
# the prime numbers are:  1566
# the prime numbers are:  1568
# the prime numbers are:  1570
# the prime numbers are:  1572
# the prime numbers are:  1574
# the prime numbers are:  1576
# the prime numbers are:  1578
# the prime numbers are:  1580
# the prime numbers are:  1582
# the prime numbers are:  1584
# the prime numbers are:  1586
# the prime numbers are:  1588
# the prime numbers are:  1590
# the prime numbers are:  1592
# the prime numbers are:  1594
# the prime numbers are:  1596
# the prime numbers are:  1598
# the prime numbers are:  1600
# the prime numbers are:  1602
# the prime numbers are:  1604
# the prime numbers are:  1606
# the prime numbers are:  1608
# the prime numbers are:  1610
# the prime numbers are:  1612
# the prime numbers are:  1614
# the prime numbers are:  1616
# the prime numbers are:  1618
# the prime numbers are:  1620
# the prime numbers are:  1622
# the prime numbers are:  1624
# the prime numbers are:  1626
# the prime numbers are:  1628
# the prime numbers are:  1630
# the prime numbers are:  1632
# the prime numbers are:  1634
# the prime numbers are:  1636
# the prime numbers are:  1638
# the prime numbers are:  1640
# the prime numbers are:  1642
# the prime numbers are:  1644
# the prime numbers are:  1646
# the prime numbers are:  1648
# the prime numbers are:  1650
# the prime numbers are:  1652
# the prime numbers are:  1654
# the prime numbers are:  1656
# the prime numbers are:  1658
# the prime numbers are:  1660
# the prime numbers are:  1662
# the prime numbers are:  1664
# the prime numbers are:  1666
# the prime numbers are:  1668
# the prime numbers are:  1670
# the prime numbers are:  1672
# the prime numbers are:  1674
# the prime numbers are:  1676
# the prime numbers are:  1678
# the prime numbers are:  1680
# the prime numbers are:  1682
# the prime numbers are:  1684
# the prime numbers are:  1686
# the prime numbers are:  1688
# the prime numbers are:  1690
# the prime numbers are:  1692
# the prime numbers are:  1694
# the prime numbers are:  1696
# the prime numbers are:  1698
# the prime numbers are:  1700
# the prime numbers are:  1702
# the prime numbers are:  1704
# the prime numbers are:  1706
# the prime numbers are:  1708
# the prime numbers are:  1710
# the prime numbers are:  1712
# the prime numbers are:  1714
# the prime numbers are:  1716
# the prime numbers are:  1718
# the prime numbers are:  1720
# the prime numbers are:  1722
# the prime numbers are:  1724
# the prime numbers are:  1726
# the prime numbers are:  1728
# the prime numbers are:  1730
# the prime numbers are:  1732
# the prime numbers are:  1734
# the prime numbers are:  1736
# the prime numbers are:  1738
# the prime numbers are:  1740
# the prime numbers are:  1742
# the prime numbers are:  1744
# the prime numbers are:  1746
# the prime numbers are:  1748
# the prime numbers are:  1750
# the prime numbers are:  1752
# the prime numbers are:  1754
# the prime numbers are:  1756
# the prime numbers are:  1758
# the prime numbers are:  1760
# the prime numbers are:  1762
# the prime numbers are:  1764
# the prime numbers are:  1766
# the prime numbers are:  1768
# the prime numbers are:  1770
# the prime numbers are:  1772
# the prime numbers are:  1774
# the prime numbers are:  1776
# the prime numbers are:  1778
# the prime numbers are:  1780
# the prime numbers are:  1782
# the prime numbers are:  1784
# the prime numbers are:  1786
# the prime numbers are:  1788
# the prime numbers are:  1790
# the prime numbers are:  1792
# the prime numbers are:  1794
# the prime numbers are:  1796
# the prime numbers are:  1798
# the prime numbers are:  1800
# the prime numbers are:  1802
# the prime numbers are:  1804
# the prime numbers are:  1806
# the prime numbers are:  1808
# the prime numbers are:  1810
# the prime numbers are:  1812
# the prime numbers are:  1814
# the prime numbers are:  1816
# the prime numbers are:  1818
# the prime numbers are:  1820
# the prime numbers are:  1822
# the prime numbers are:  1824
# the prime numbers are:  1826
# the prime numbers are:  1828
# the prime numbers are:  1830
# the prime numbers are:  1832
# the prime numbers are:  1834
# the prime numbers are:  1836
# the prime numbers are:  1838
# the prime numbers are:  1840
# the prime numbers are:  1842
# the prime numbers are:  1844
# the prime numbers are:  1846
# the prime numbers are:  1848
# the prime numbers are:  1850
# the prime numbers are:  1852
# the prime numbers are:  1854
# the prime numbers are:  1856
# the prime numbers are:  1858
# the prime numbers are:  1860
# the prime numbers are:  1862
# the prime numbers are:  1864
# the prime numbers are:  1866
# the prime numbers are:  1868
# the prime numbers are:  1870
# the prime numbers are:  1872
# the prime numbers are:  1874
# the prime numbers are:  1876
# the prime numbers are:  1878
# the prime numbers are:  1880
# the prime numbers are:  1882
# the prime numbers are:  1884
# the prime numbers are:  1886
# the prime numbers are:  1888
# the prime numbers are:  1890
# the prime numbers are:  1892
# the prime numbers are:  1894
# the prime numbers are:  1896
# the prime numbers are:  1898
# the prime numbers are:  1900
# the prime numbers are:  1902
# the prime numbers are:  1904
# the prime numbers are:  1906
# the prime numbers are:  1908
# the prime numbers are:  1910
# the prime numbers are:  1912
# the prime numbers are:  1914
# the prime numbers are:  1916
# the prime numbers are:  1918
# the prime numbers are:  1920
# the prime numbers are:  1922
# the prime numbers are:  1924
# the prime numbers are:  1926
# the prime numbers are:  1928
# the prime numbers are:  1930
# the prime numbers are:  1932
# the prime numbers are:  1934
# the prime numbers are:  1936
# the prime numbers are:  1938
# the prime numbers are:  1940
# the prime numbers are:  1942
# the prime numbers are:  1944
# the prime numbers are:  1946
# the prime numbers are:  1948
# the prime numbers are:  1950
# the prime numbers are:  1952
# the prime numbers are:  1954
# the prime numbers are:  1956
# the prime numbers are:  1958
# the prime numbers are:  1960
# the prime numbers are:  1962
# the prime numbers are:  1964
# the prime numbers are:  1966
# the prime numbers are:  1968
# the prime numbers are:  1970
# the prime numbers are:  1972
# the prime numbers are:  1974
# the prime numbers are:  1976
# the prime numbers are:  1978
# the prime numbers are:  1980
# the prime numbers are:  1982
# the prime numbers are:  1984
# the prime numbers are:  1986
# the prime numbers are:  1988
# the prime numbers are:  1990
# the prime numbers are:  1992
# the prime numbers are:  1994
# the prime numbers are:  1996
# the prime numbers are:  1998
# the prime numbers are:  2000
# the prime numbers are:  2002
# the prime numbers are:  2004
# the prime numbers are:  2006
# the prime numbers are:  2008
# the prime numbers are:  2010
# the prime numbers are:  2012
# the prime numbers are:  2014
# the prime numbers are:  2016
# the prime numbers are:  2018
# the prime numbers are:  2020
# the prime numbers are:  2022
# the prime numbers are:  2024
# the prime numbers are:  2026
# the prime numbers are:  2028
# the prime numbers are:  2030
# the prime numbers are:  2032
# the prime numbers are:  2034
# the prime numbers are:  2036
# the prime numbers are:  2038
# the prime numbers are:  2040
# the prime numbers are:  2042
# the prime numbers are:  2044
# the prime numbers are:  2046
# the prime numbers are:  2048
# the prime numbers are:  2050
# the prime numbers are:  2052
# the prime numbers are:  2054
# the prime numbers are:  2056
# the prime numbers are:  2058
# the prime numbers are:  2060
# the prime numbers are:  2062
# the prime numbers are:  2064
# the prime numbers are:  2066
# the prime numbers are:  2068
# the prime numbers are:  2070
# the prime numbers are:  2072
# the prime numbers are:  2074
# the prime numbers are:  2076
# the prime numbers are:  2078
# the prime numbers are:  2080
# the prime numbers are:  2082
# the prime numbers are:  2084
# the prime numbers are:  2086
# the prime numbers are:  2088
# the prime numbers are:  2090
# the prime numbers are:  2092
# the prime numbers are:  2094
# the prime numbers are:  2096
# the prime numbers are:  2098
# the prime numbers are:  2100
# the prime numbers are:  2102
# the prime numbers are:  2104
# the prime numbers are:  2106
# the prime numbers are:  2108
# the prime numbers are:  2110
# the prime numbers are:  2112
# the prime numbers are:  2114
# the prime numbers are:  2116
# the prime numbers are:  2118
# the prime numbers are:  2120
# the prime numbers are:  2122
# the prime numbers are:  2124
# the prime numbers are:  2126
# the prime numbers are:  2128
# the prime numbers are:  2130
# the prime numbers are:  2132
# the prime numbers are:  2134
# the prime numbers are:  2136
# the prime numbers are:  2138
# the prime numbers are:  2140
# the prime numbers are:  2142
# the prime numbers are:  2144
# the prime numbers are:  2146
# the prime numbers are:  2148
# the prime numbers are:  2150
# the prime numbers are:  2152
# the prime numbers are:  2154
# the prime numbers are:  2156
# the prime numbers are:  2158
# the prime numbers are:  2160
# the prime numbers are:  2162
# the prime numbers are:  2164
# the prime numbers are:  2166
# the prime numbers are:  2168
# the prime numbers are:  2170
# the prime numbers are:  2172
# the prime numbers are:  2174
# the prime numbers are:  2176
# the prime numbers are:  2178
# the prime numbers are:  2180
# the prime numbers are:  2182
# the prime numbers are:  2184
# the prime numbers are:  2186
# the prime numbers are:  2188
# the prime numbers are:  2190
# the prime numbers are:  2192
# the prime numbers are:  2194
# the prime numbers are:  2196
# the prime numbers are:  2198
# the prime numbers are:  2200
# the prime numbers are:  2202
# the prime numbers are:  2204
# the prime numbers are:  2206
# the prime numbers are:  2208
# the prime numbers are:  2210
# the prime numbers are:  2212
# the prime numbers are:  2214
# the prime numbers are:  2216
# the prime numbers are:  2218
# the prime numbers are:  2220
# the prime numbers are:  2222
# the prime numbers are:  2224
# the prime numbers are:  2226
# the prime numbers are:  2228
# the prime numbers are:  2230
# the prime numbers are:  2232
# the prime numbers are:  2234
# the prime numbers are:  2236
# the prime numbers are:  2238
# the prime numbers are:  2240
# the prime numbers are:  2242
# the prime numbers are:  2244
# the prime numbers are:  2246
# the prime numbers are:  2248
# the prime numbers are:  2250
# the prime numbers are:  2252
# the prime numbers are:  2254
# the prime numbers are:  2256
# the prime numbers are:  2258
# the prime numbers are:  2260
# the prime numbers are:  2262
# the prime numbers are:  2264
# the prime numbers are:  2266
# the prime numbers are:  2268
# the prime numbers are:  2270
# the prime numbers are:  2272
# the prime numbers are:  2274
# the prime numbers are:  2276
# the prime numbers are:  2278
# the prime numbers are:  2280
# the prime numbers are:  2282
# the prime numbers are:  2284
# the prime numbers are:  2286
# the prime numbers are:  2288
# the prime numbers are:  2290
# the prime numbers are:  2292
# the prime numbers are:  2294
# the prime numbers are:  2296
# the prime numbers are:  2298
# the prime numbers are:  2300
# the prime numbers are:  2302
# the prime numbers are:  2304
# the prime numbers are:  2306
# the prime numbers are:  2308
# the prime numbers are:  2310
# the prime numbers are:  2312
# the prime numbers are:  2314
# the prime numbers are:  2316
# the prime numbers are:  2318
# the prime numbers are:  2320
# the prime numbers are:  2322
# the prime numbers are:  2324
# the prime numbers are:  2326
# the prime numbers are:  2328
# the prime numbers are:  2330
# the prime numbers are:  2332
# the prime numbers are:  2334
# the prime numbers are:  2336
# the prime numbers are:  2338
# the prime numbers are:  2340
# the prime numbers are:  2342
# the prime numbers are:  2344
# the prime numbers are:  2346
# the prime numbers are:  2348
# the prime numbers are:  2350
# the prime numbers are:  2352
# the prime numbers are:  2354
# the prime numbers are:  2356
# the prime numbers are:  2358
# the prime numbers are:  2360
# the prime numbers are:  2362
# the prime numbers are:  2364
# the prime numbers are:  2366
# the prime numbers are:  2368
# the prime numbers are:  2370
# the prime numbers are:  2372
# the prime numbers are:  2374
# the prime numbers are:  2376
# the prime numbers are:  2378
# the prime numbers are:  2380
# the prime numbers are:  2382
# the prime numbers are:  2384
# the prime numbers are:  2386
# the prime numbers are:  2388
# the prime numbers are:  2390
# the prime numbers are:  2392
# the prime numbers are:  2394
# the prime numbers are:  2396
# the prime numbers are:  2398
# the prime numbers are:  2400
# the prime numbers are:  2402
# the prime numbers are:  2404
# the prime numbers are:  2406
# the prime numbers are:  2408
# the prime numbers are:  2410
# the prime numbers are:  2412
# the prime numbers are:  2414
# the prime numbers are:  2416
# the prime numbers are:  2418
# the prime numbers are:  2420
# the prime numbers are:  2422
# the prime numbers are:  2424
# the prime numbers are:  2426
# the prime numbers are:  2428
# the prime numbers are:  2430
# the prime numbers are:  2432
# the prime numbers are:  2434
# the prime numbers are:  2436
# the prime numbers are:  2438
# the prime numbers are:  2440
# the prime numbers are:  2442
# the prime numbers are:  2444
# the prime numbers are:  2446
# the prime numbers are:  2448
# the prime numbers are:  2450
# the prime numbers are:  2452
# the prime numbers are:  2454
# the prime numbers are:  2456
# the prime numbers are:  2458
# the prime numbers are:  2460
# the prime numbers are:  2462
# the prime numbers are:  2464
# the prime numbers are:  2466
# the prime numbers are:  2468
# the prime numbers are:  2470
# the prime numbers are:  2472
# the prime numbers are:  2474
# the prime numbers are:  2476
# the prime numbers are:  2478
# the prime numbers are:  2480
# the prime numbers are:  2482
# the prime numbers are:  2484
# the prime numbers are:  2486
# the prime numbers are:  2488
# the prime numbers are:  2490
# the prime numbers are:  2492
# the prime numbers are:  2494
# the prime numbers are:  2496
# the prime numbers are:  2498
# the prime numbers are:  2500
# the prime numbers are:  2502
# the prime numbers are:  2504
# the prime numbers are:  2506
# the prime numbers are:  2508
# the prime numbers are:  2510
# the prime numbers are:  2512
# the prime numbers are:  2514
# the prime numbers are:  2516
# the prime numbers are:  2518
# the prime numbers are:  2520
# the prime numbers are:  2522
# the prime numbers are:  2524
# the prime numbers are:  2526
# the prime numbers are:  2528
# the prime numbers are:  2530
# the prime numbers are:  2532
# the prime numbers are:  2534
# the prime numbers are:  2536
# the prime numbers are:  2538
# the prime numbers are:  2540
# the prime numbers are:  2542
# the prime numbers are:  2544
# the prime numbers are:  2546
# the prime numbers are:  2548
# the prime numbers are:  2550
# the prime numbers are:  2552
# the prime numbers are:  2554
# the prime numbers are:  2556
# the prime numbers are:  2558
# the prime numbers are:  2560
# the prime numbers are:  2562
# the prime numbers are:  2564
# the prime numbers are:  2566
# the prime numbers are:  2568
# the prime numbers are:  2570
# the prime numbers are:  2572
# the prime numbers are:  2574
# the prime numbers are:  2576
# the prime numbers are:  2578
# the prime numbers are:  2580
# the prime numbers are:  2582
# the prime numbers are:  2584
# the prime numbers are:  2586
# the prime numbers are:  2588
# the prime numbers are:  2590
# the prime numbers are:  2592
# the prime numbers are:  2594
# the prime numbers are:  2596
# the prime numbers are:  2598
# the prime numbers are:  2600
# the prime numbers are:  2602
# the prime numbers are:  2604
# the prime numbers are:  2606
# the prime numbers are:  2608
# the prime numbers are:  2610
# the prime numbers are:  2612
# the prime numbers are:  2614
# the prime numbers are:  2616
# the prime numbers are:  2618
# the prime numbers are:  2620
# the prime numbers are:  2622
# the prime numbers are:  2624
# the prime numbers are:  2626
# the prime numbers are:  2628
# the prime numbers are:  2630
# the prime numbers are:  2632
# the prime numbers are:  2634
# the prime numbers are:  2636
# the prime numbers are:  2638
# the prime numbers are:  2640
# the prime numbers are:  2642
# the prime numbers are:  2644
# the prime numbers are:  2646
# the prime numbers are:  2648
# the prime numbers are:  2650
# the prime numbers are:  2652
# the prime numbers are:  2654
# the prime numbers are:  2656
# the prime numbers are:  2658
# the prime numbers are:  2660
# the prime numbers are:  2662
# the prime numbers are:  2664
# the prime numbers are:  2666
# the prime numbers are:  2668
# the prime numbers are:  2670
# the prime numbers are:  2672
# the prime numbers are:  2674
# the prime numbers are:  2676
# the prime numbers are:  2678
# the prime numbers are:  2680
# the prime numbers are:  2682
# the prime numbers are:  2684
# the prime numbers are:  2686
# the prime numbers are:  2688
# the prime numbers are:  2690
# the prime numbers are:  2692
# the prime numbers are:  2694
# the prime numbers are:  2696
# the prime numbers are:  2698
# the prime numbers are:  2700
# the prime numbers are:  2702
# the prime numbers are:  2704
# the prime numbers are:  2706
# the prime numbers are:  2708
# the prime numbers are:  2710
# the prime numbers are:  2712
# the prime numbers are:  2714
# the prime numbers are:  2716
# the prime numbers are:  2718
# the prime numbers are:  2720
# the prime numbers are:  2722
# the prime numbers are:  2724
# the prime numbers are:  2726
# the prime numbers are:  2728
# the prime numbers are:  2730
# the prime numbers are:  2732
# the prime numbers are:  2734
# the prime numbers are:  2736
# the prime numbers are:  2738
# the prime numbers are:  2740
# the prime numbers are:  2742
# the prime numbers are:  2744
# the prime numbers are:  2746
# the prime numbers are:  2748
# the prime numbers are:  2750
# the prime numbers are:  2752
# the prime numbers are:  2754
# the prime numbers are:  2756
# the prime numbers are:  2758
# the prime numbers are:  2760
# the prime numbers are:  2762
# the prime numbers are:  2764
# the prime numbers are:  2766
# the prime numbers are:  2768
# the prime numbers are:  2770
# the prime numbers are:  2772
# the prime numbers are:  2774
# the prime numbers are:  2776
# the prime numbers are:  2778
# the prime numbers are:  2780
# the prime numbers are:  2782
# the prime numbers are:  2784
# the prime numbers are:  2786
# the prime numbers are:  2788
# the prime numbers are:  2790
# the prime numbers are:  2792
# the prime numbers are:  2794
# the prime numbers are:  2796
# the prime numbers are:  2798
# the prime numbers are:  2800
# the prime numbers are:  2802
# the prime numbers are:  2804
# the prime numbers are:  2806
# the prime numbers are:  2808
# the prime numbers are:  2810
# the prime numbers are:  2812
# the prime numbers are:  2814
# the prime numbers are:  2816
# the prime numbers are:  2818
# the prime numbers are:  2820
# the prime numbers are:  2822
# the prime numbers are:  2824
# the prime numbers are:  2826
# the prime numbers are:  2828
# the prime numbers are:  2830
# the prime numbers are:  2832
# the prime numbers are:  2834
# the prime numbers are:  2836
# the prime numbers are:  2838
# the prime numbers are:  2840
# the prime numbers are:  2842
# the prime numbers are:  2844
# the prime numbers are:  2846
# the prime numbers are:  2848
# the prime numbers are:  2850
# the prime numbers are:  2852
# the prime numbers are:  2854
# the prime numbers are:  2856
# the prime numbers are:  2858
# the prime numbers are:  2860
# the prime numbers are:  2862
# the prime numbers are:  2864
# the prime numbers are:  2866
# the prime numbers are:  2868
# the prime numbers are:  2870
# the prime numbers are:  2872
# the prime numbers are:  2874
# the prime numbers are:  2876
# the prime numbers are:  2878
# the prime numbers are:  2880
# the prime numbers are:  2882
# the prime numbers are:  2884
# the prime numbers are:  2886
# the prime numbers are:  2888
# the prime numbers are:  2890
# the prime numbers are:  2892
# the prime numbers are:  2894
# the prime numbers are:  2896
# the prime numbers are:  2898
# the prime numbers are:  2900
# the prime numbers are:  2902
# the prime numbers are:  2904
# the prime numbers are:  2906
# the prime numbers are:  2908
# the prime numbers are:  2910
# the prime numbers are:  2912
# the prime numbers are:  2914
# the prime numbers are:  2916
# the prime numbers are:  2918
# the prime numbers are:  2920
# the prime numbers are:  2922
# the prime numbers are:  2924
# the prime numbers are:  2926
# the prime numbers are:  2928
# the prime numbers are:  2930
# the prime numbers are:  2932
# the prime numbers are:  2934
# the prime numbers are:  2936
# the prime numbers are:  2938
# the prime numbers are:  2940
# the prime numbers are:  2942
# the prime numbers are:  2944
# the prime numbers are:  2946
# the prime numbers are:  2948
# the prime numbers are:  2950
# the prime numbers are:  2952
# the prime numbers are:  2954
# the prime numbers are:  2956
# the prime numbers are:  2958
# the prime numbers are:  2960
# the prime numbers are:  2962
# the prime numbers are:  2964
# the prime numbers are:  2966
# the prime numbers are:  2968
# the prime numbers are:  2970
# the prime numbers are:  2972
# the prime numbers are:  2974
# the prime numbers are:  2976
# the prime numbers are:  2978
# the prime numbers are:  2980
# the prime numbers are:  2982
# the prime numbers are:  2984
# the prime numbers are:  2986
# the prime numbers are:  2988
# the prime numbers are:  2990
# the prime numbers are:  2992
# the prime numbers are:  2994
# the prime numbers are:  2996
# the prime numbers are:  2998
# the prime numbers are:  3000
# the prime numbers are:  3002
# the prime numbers are:  3004
# the prime numbers are:  3006
# the prime numbers are:  3008
# the prime numbers are:  3010
# the prime numbers are:  3012
# the prime numbers are:  3014
# the prime numbers are:  3016
# the prime numbers are:  3018
# the prime numbers are:  3020
# the prime numbers are:  3022
# the prime numbers are:  3024
# the prime numbers are:  3026
# the prime numbers are:  3028
# the prime numbers are:  3030
# the prime numbers are:  3032
# the prime numbers are:  3034
# the prime numbers are:  3036
# the prime numbers are:  3038
# the prime numbers are:  3040
# the prime numbers are:  3042
# the prime numbers are:  3044
# the prime numbers are:  3046
# the prime numbers are:  3048
# the prime numbers are:  3050
# the prime numbers are:  3052
# the prime numbers are:  3054
# the prime numbers are:  3056
# the prime numbers are:  3058
# the prime numbers are:  3060
# the prime numbers are:  3062
# the prime numbers are:  3064
# the prime numbers are:  3066
# the prime numbers are:  3068
# the prime numbers are:  3070
# the prime numbers are:  3072
# the prime numbers are:  3074
# the prime numbers are:  3076
# the prime numbers are:  3078
# the prime numbers are:  3080
# the prime numbers are:  3082
# the prime numbers are:  3084
# the prime numbers are:  3086
# the prime numbers are:  3088
# the prime numbers are:  3090
# the prime numbers are:  3092
# the prime numbers are:  3094
# the prime numbers are:  3096
# the prime numbers are:  3098
# the prime numbers are:  3100
# the prime numbers are:  3102
# the prime numbers are:  3104
# the prime numbers are:  3106
# the prime numbers are:  3108
# the prime numbers are:  3110
# the prime numbers are:  3112
# the prime numbers are:  3114
# the prime numbers are:  3116
# the prime numbers are:  3118
# the prime numbers are:  3120
# the prime numbers are:  3122
# the prime numbers are:  3124
# the prime numbers are:  3126
# the prime numbers are:  3128
# the prime numbers are:  3130
# the prime numbers are:  3132
# the prime numbers are:  3134
# the prime numbers are:  3136
# the prime numbers are:  3138
# the prime numbers are:  3140
# the prime numbers are:  3142
# the prime numbers are:  3144
# the prime numbers are:  3146
# the prime numbers are:  3148
# the prime numbers are:  3150
# the prime numbers are:  3152
# the prime numbers are:  3154
# the prime numbers are:  3156
# the prime numbers are:  3158
# the prime numbers are:  3160
# the prime numbers are:  3162
# the prime numbers are:  3164
# the prime numbers are:  3166
# the prime numbers are:  3168
# the prime numbers are:  3170
# the prime numbers are:  3172
# the prime numbers are:  3174
# the prime numbers are:  3176
# the prime numbers are:  3178
# the prime numbers are:  3180
# the prime numbers are:  3182
# the prime numbers are:  3184
# the prime numbers are:  3186
# the prime numbers are:  3188
# the prime numbers are:  3190
# the prime numbers are:  3192
# the prime numbers are:  3194
# the prime numbers are:  3196
# the prime numbers are:  3198
# the prime numbers are:  3200
# the prime numbers are:  3202
# the prime numbers are:  3204
# the prime numbers are:  3206
# the prime numbers are:  3208
# the prime numbers are:  3210
# the prime numbers are:  3212
# the prime numbers are:  3214
# the prime numbers are:  3216
# the prime numbers are:  3218
# the prime numbers are:  3220
# the prime numbers are:  3222
# the prime numbers are:  3224
# the prime numbers are:  3226
# the prime numbers are:  3228
# the prime numbers are:  3230
# the prime numbers are:  3232
# the prime numbers are:  3234
# the prime numbers are:  3236
# the prime numbers are:  3238
# the prime numbers are:  3240
# the prime numbers are:  3242
# the prime numbers are:  3244
# the prime numbers are:  3246
# the prime numbers are:  3248
# the prime numbers are:  3250
# the prime numbers are:  3252
# the prime numbers are:  3254
# the prime numbers are:  3256
# the prime numbers are:  3258
# the prime numbers are:  3260
# the prime numbers are:  3262
# the prime numbers are:  3264
# the prime numbers are:  3266
# the prime numbers are:  3268
# the prime numbers are:  3270
# the prime numbers are:  3272
# the prime numbers are:  3274
# the prime numbers are:  3276
# the prime numbers are:  3278
# the prime numbers are:  3280
# the prime numbers are:  3282
# the prime numbers are:  3284
# the prime numbers are:  3286
# the prime numbers are:  3288
# the prime numbers are:  3290
# the prime numbers are:  3292
# the prime numbers are:  3294
# the prime numbers are:  3296
# the prime numbers are:  3298
# the prime numbers are:  3300
# the prime numbers are:  3302
# the prime numbers are:  3304
# the prime numbers are:  3306
# the prime numbers are:  3308
# the prime numbers are:  3310
# the prime numbers are:  3312
# the prime numbers are:  3314
# the prime numbers are:  3316
# the prime numbers are:  3318
# the prime numbers are:  3320
# the prime numbers are:  3322
# the prime numbers are:  3324
# the prime numbers are:  3326
# the prime numbers are:  3328
# the prime numbers are:  3330
# the prime numbers are:  3332
# the prime numbers are:  3334
# the prime numbers are:  3336
# the prime numbers are:  3338
# the prime numbers are:  3340
# the prime numbers are:  3342
# the prime numbers are:  3344
# the prime numbers are:  3346
# ...
# the prime numbers are:  8898
# the prime numbers are:  8900
# the prime numbers are:  8902
# the prime numbers are:  8904
# the prime numbers are:  8906
# the prime numbers are:  8908
# the prime numbers are:  8910
# the prime numbers are:  8912
# the prime numbers are:  8914
# the prime numbers are:  8916
# the prime numbers are:  8918
# the prime numbers are:  8920
# the prime numbers are:  8922
# the prime numbers are:  8924
# the prime numbers are:  8926
# the prime numbers are:  8928
# the prime numbers are:  8930
# the prime numbers are:  8932
# the prime numbers are:  8934
# the prime numbers are:  8936
# the prime numbers are:  8938
# the prime numbers are:  8940
# the prime numbers are:  8942
# the prime numbers are:  8944
# the prime numbers are:  8946
# the prime numbers are:  8948
# the prime numbers are:  8950
# the prime numbers are:  8952
# the prime numbers are:  8954
# the prime numbers are:  8956
# the prime numbers are:  8958
# the prime numbers are:  8960
# the prime numbers are:  8962
# the prime numbers are:  8964
# the prime numbers are:  8966
# the prime numbers are:  8968
# the prime numbers are:  8970
# the prime numbers are:  8972
# the prime numbers are:  8974
# the prime numbers are:  8976
# the prime numbers are:  8978
# the prime numbers are:  8980
# the prime numbers are:  8982
# the prime numbers are:  8984
# the prime numbers are:  8986
# the prime numbers are:  8988
# the prime numbers are:  8990
# the prime numbers are:  8992
# the prime numbers are:  8994
# the prime numbers are:  8996
# the prime numbers are:  8998
# the prime numbers are:  9000
# the prime numbers are:  9002
# the prime numbers are:  9004
# the prime numbers are:  9006
# the prime numbers are:  9008
# the prime numbers are:  9010
# the prime numbers are:  9012
# the prime numbers are:  9014
# the prime numbers are:  9016
# the prime numbers are:  9018
# the prime numbers are:  9020
# the prime numbers are:  9022
# the prime numbers are:  9024
# the prime numbers are:  9026
# the prime numbers are:  9028
# the prime numbers are:  9030
# the prime numbers are:  9032
# the prime numbers are:  9034
# the prime numbers are:  9036
# the prime numbers are:  9038
# the prime numbers are:  9040
# the prime numbers are:  9042
# the prime numbers are:  9044
# the prime numbers are:  9046
# the prime numbers are:  9048
# the prime numbers are:  9050
# the prime numbers are:  9052
# the prime numbers are:  9054
# the prime numbers are:  9056
# the prime numbers are:  9058
# the prime numbers are:  9060
# the prime numbers are:  9062
# the prime numbers are:  9064
# the prime numbers are:  9066
# the prime numbers are:  9068
# the prime numbers are:  9070
# the prime numbers are:  9072
# the prime numbers are:  9074
# the prime numbers are:  9076
# the prime numbers are:  9078
# the prime numbers are:  9080
# the prime numbers are:  9082
# the prime numbers are:  9084
# the prime numbers are:  9086
# the prime numbers are:  9088
# the prime numbers are:  9090
# the prime numbers are:  9092
# the prime numbers are:  9094
# the prime numbers are:  9096
# the prime numbers are:  9098
# the prime numbers are:  9100
# the prime numbers are:  9102
# the prime numbers are:  9104
# the prime numbers are:  9106
# the prime numbers are:  9108
# the prime numbers are:  9110
# the prime numbers are:  9112
# the prime numbers are:  9114
# the prime numbers are:  9116
# the prime numbers are:  9118
# the prime numbers are:  9120
# the prime numbers are:  9122
# the prime numbers are:  9124
# the prime numbers are:  9126
# the prime numbers are:  9128
# the prime numbers are:  9130
# the prime numbers are:  9132
# the prime numbers are:  9134
# the prime numbers are:  9136
# the prime numbers are:  9138
# the prime numbers are:  9140
# the prime numbers are:  9142
# the prime numbers are:  9144
# the prime numbers are:  9146
# the prime numbers are:  9148
# the prime numbers are:  9150
# the prime numbers are:  9152
# the prime numbers are:  9154
# the prime numbers are:  9156
# the prime numbers are:  9158
# the prime numbers are:  9160
# the prime numbers are:  9162
# the prime numbers are:  9164
# the prime numbers are:  9166
# the prime numbers are:  9168
# the prime numbers are:  9170
# the prime numbers are:  9172
# the prime numbers are:  9174
# the prime numbers are:  9176
# the prime numbers are:  9178
# the prime numbers are:  9180
# the prime numbers are:  9182
# the prime numbers are:  9184
# the prime numbers are:  9186
# the prime numbers are:  9188
# the prime numbers are:  9190
# the prime numbers are:  9192
# the prime numbers are:  9194
# the prime numbers are:  9196
# the prime numbers are:  9198
# the prime numbers are:  9200
# the prime numbers are:  9202
# the prime numbers are:  9204
# the prime numbers are:  9206
# the prime numbers are:  9208
# the prime numbers are:  9210
# the prime numbers are:  9212
# the prime numbers are:  9214
# the prime numbers are:  9216
# the prime numbers are:  9218
# the prime numbers are:  9220
# the prime numbers are:  9222
# the prime numbers are:  9224
# the prime numbers are:  9226
# the prime numbers are:  9228
# the prime numbers are:  9230
# the prime numbers are:  9232
# the prime numbers are:  9234
# the prime numbers are:  9236
# the prime numbers are:  9238
# the prime numbers are:  9240
# the prime numbers are:  9242
# the prime numbers are:  9244
# the prime numbers are:  9246
# the prime numbers are:  9248
# the prime numbers are:  9250
# the prime numbers are:  9252
# the prime numbers are:  9254
# the prime numbers are:  9256
# the prime numbers are:  9258
# the prime numbers are:  9260
# the prime numbers are:  9262
# the prime numbers are:  9264
# the prime numbers are:  9266
# the prime numbers are:  9268
# the prime numbers are:  9270
# the prime numbers are:  9272
# the prime numbers are:  9274
# the prime numbers are:  9276
# the prime numbers are:  9278
# the prime numbers are:  9280
# the prime numbers are:  9282
# the prime numbers are:  9284
# the prime numbers are:  9286
# the prime numbers are:  9288
# the prime numbers are:  9290
# the prime numbers are:  9292
# the prime numbers are:  9294
# the prime numbers are:  9296
# the prime numbers are:  9298
# the prime numbers are:  9300
# the prime numbers are:  9302
# the prime numbers are:  9304
# the prime numbers are:  9306
# the prime numbers are:  9308
# the prime numbers are:  9310
# the prime numbers are:  9312
# the prime numbers are:  9314
# the prime numbers are:  9316
# the prime numbers are:  9318
# the prime numbers are:  9320
# the prime numbers are:  9322
# the prime numbers are:  9324
# the prime numbers are:  9326
# the prime numbers are:  9328
# the prime numbers are:  9330
# the prime numbers are:  9332
# the prime numbers are:  9334
# the prime numbers are:  9336
# the prime numbers are:  9338
# the prime numbers are:  9340
# the prime numbers are:  9342
# the prime numbers are:  9344
# the prime numbers are:  9346
# the prime numbers are:  9348
# the prime numbers are:  9350
# the prime numbers are:  9352
# the prime numbers are:  9354
# the prime numbers are:  9356
# the prime numbers are:  9358
# the prime numbers are:  9360
# the prime numbers are:  9362
# the prime numbers are:  9364
# the prime numbers are:  9366
# the prime numbers are:  9368
# the prime numbers are:  9370
# the prime numbers are:  9372
# the prime numbers are:  9374
# the prime numbers are:  9376
# the prime numbers are:  9378
# the prime numbers are:  9380
# the prime numbers are:  9382
# the prime numbers are:  9384
# the prime numbers are:  9386
# the prime numbers are:  9388
# the prime numbers are:  9390
# the prime numbers are:  9392
# the prime numbers are:  9394
# the prime numbers are:  9396
# the prime numbers are:  9398
# the prime numbers are:  9400
# the prime numbers are:  9402
# the prime numbers are:  9404
# the prime numbers are:  9406
# the prime numbers are:  9408
# the prime numbers are:  9410
# the prime numbers are:  9412
# the prime numbers are:  9414
# the prime numbers are:  9416
# the prime numbers are:  9418
# the prime numbers are:  9420
# the prime numbers are:  9422
# the prime numbers are:  9424
# the prime numbers are:  9426
# the prime numbers are:  9428
# the prime numbers are:  9430
# the prime numbers are:  9432
# the prime numbers are:  9434
# the prime numbers are:  9436
# the prime numbers are:  9438
# the prime numbers are:  9440
# the prime numbers are:  9442
# the prime numbers are:  9444
# the prime numbers are:  9446
# the prime numbers are:  9448
# the prime numbers are:  9450
# the prime numbers are:  9452
# the prime numbers are:  9454
# the prime numbers are:  9456
# the prime numbers are:  9458
# the prime numbers are:  9460
# the prime numbers are:  9462
# the prime numbers are:  9464
# the prime numbers are:  9466
# the prime numbers are:  9468
# the prime numbers are:  9470
# the prime numbers are:  9472
# the prime numbers are:  9474
# the prime numbers are:  9476
# the prime numbers are:  9478
# the prime numbers are:  9480
# the prime numbers are:  9482
# the prime numbers are:  9484
# the prime numbers are:  9486
# the prime numbers are:  9488
# the prime numbers are:  9490
# the prime numbers are:  9492
# the prime numbers are:  9494
# the prime numbers are:  9496
# the prime numbers are:  9498
# the prime numbers are:  9500
# the prime numbers are:  9502
# the prime numbers are:  9504
# the prime numbers are:  9506
# the prime numbers are:  9508
# the prime numbers are:  9510
# the prime numbers are:  9512
# the prime numbers are:  9514
# the prime numbers are:  9516
# the prime numbers are:  9518
# the prime numbers are:  9520
# the prime numbers are:  9522
# the prime numbers are:  9524
# the prime numbers are:  9526
# the prime numbers are:  9528
# the prime numbers are:  9530
# the prime numbers are:  9532
# the prime numbers are:  9534
# the prime numbers are:  9536
# the prime numbers are:  9538
# the prime numbers are:  9540
# the prime numbers are:  9542
# the prime numbers are:  9544
# the prime numbers are:  9546
# the prime numbers are:  9548
# the prime numbers are:  9550
# the prime numbers are:  9552
# the prime numbers are:  9554
# the prime numbers are:  9556
# the prime numbers are:  9558
# the prime numbers are:  9560
# the prime numbers are:  9562
# the prime numbers are:  9564
# the prime numbers are:  9566
# the prime numbers are:  9568
# the prime numbers are:  9570
# the prime numbers are:  9572
# the prime numbers are:  9574
# the prime numbers are:  9576
# the prime numbers are:  9578
# the prime numbers are:  9580
# the prime numbers are:  9582
# the prime numbers are:  9584
# the prime numbers are:  9586
# the prime numbers are:  9588
# the prime numbers are:  9590
# the prime numbers are:  9592
# the prime numbers are:  9594
# the prime numbers are:  9596
# the prime numbers are:  9598
# the prime numbers are:  9600
# the prime numbers are:  9602
# the prime numbers are:  9604
# the prime numbers are:  9606
# the prime numbers are:  9608
# the prime numbers are:  9610
# the prime numbers are:  9612
# the prime numbers are:  9614
# the prime numbers are:  9616
# the prime numbers are:  9618
# the prime numbers are:  9620
# the prime numbers are:  9622
# the prime numbers are:  9624
# the prime numbers are:  9626
# the prime numbers are:  9628
# the prime numbers are:  9630
# the prime numbers are:  9632
# the prime numbers are:  9634
# the prime numbers are:  9636
# the prime numbers are:  9638
# the prime numbers are:  9640
# the prime numbers are:  9642
# the prime numbers are:  9644
# the prime numbers are:  9646
# the prime numbers are:  9648
# the prime numbers are:  9650
# the prime numbers are:  9652
# the prime numbers are:  9654
# the prime numbers are:  9656
# the prime numbers are:  9658
# the prime numbers are:  9660
# the prime numbers are:  9662
# the prime numbers are:  9664
# the prime numbers are:  9666
# the prime numbers are:  9668
# the prime numbers are:  9670
# the prime numbers are:  9672
# the prime numbers are:  9674
# the prime numbers are:  9676
# the prime numbers are:  9678
# the prime numbers are:  9680
# the prime numbers are:  9682
# the prime numbers are:  9684
# the prime numbers are:  9686
# the prime numbers are:  9688
# the prime numbers are:  9690
# the prime numbers are:  9692
# the prime numbers are:  9694
# the prime numbers are:  9696
# the prime numbers are:  9698
# the prime numbers are:  9700
# the prime numbers are:  9702
# the prime numbers are:  9704
# the prime numbers are:  9706
# the prime numbers are:  9708
# the prime numbers are:  9710
# the prime numbers are:  9712
# the prime numbers are:  9714
# the prime numbers are:  9716
# the prime numbers are:  9718
# the prime numbers are:  9720
# the prime numbers are:  9722
# the prime numbers are:  9724
# the prime numbers are:  9726
# the prime numbers are:  9728
# the prime numbers are:  9730
# the prime numbers are:  9732
# the prime numbers are:  9734
# the prime numbers are:  9736
# the prime numbers are:  9738
# the prime numbers are:  9740
# the prime numbers are:  9742
# the prime numbers are:  9744
# the prime numbers are:  9746
# the prime numbers are:  9748
# the prime numbers are:  9750
# the prime numbers are:  9752
# the prime numbers are:  9754
# the prime numbers are:  9756
# the prime numbers are:  9758
# the prime numbers are:  9760
# the prime numbers are:  9762
# the prime numbers are:  9764
# the prime numbers are:  9766
# the prime numbers are:  9768
# the prime numbers are:  9770
# the prime numbers are:  9772
# the prime numbers are:  9774
# the prime numbers are:  9776
# the prime numbers are:  9778
# the prime numbers are:  9780
# the prime numbers are:  9782
# the prime numbers are:  9784
# the prime numbers are:  9786
# the prime numbers are:  9788
# the prime numbers are:  9790
# the prime numbers are:  9792
# the prime numbers are:  9794
# the prime numbers are:  9796
# the prime numbers are:  9798
# the prime numbers are:  9800
# the prime numbers are:  9802
# the prime numbers are:  9804
# the prime numbers are:  9806
# the prime numbers are:  9808
# the prime numbers are:  9810
# the prime numbers are:  9812
# the prime numbers are:  9814
# the prime numbers are:  9816
# the prime numbers are:  9818
# the prime numbers are:  9820
# the prime numbers are:  9822
# the prime numbers are:  9824
# the prime numbers are:  9826
# the prime numbers are:  9828
# the prime numbers are:  9830
# the prime numbers are:  9832
# the prime numbers are:  9834
# the prime numbers are:  9836
# the prime numbers are:  9838
# the prime numbers are:  9840
# the prime numbers are:  9842
# the prime numbers are:  9844
# the prime numbers are:  9846
# the prime numbers are:  9848
# the prime numbers are:  9850
# the prime numbers are:  9852
# the prime numbers are:  9854
# the prime numbers are:  9856
# the prime numbers are:  9858
# the prime numbers are:  9860
# the prime numbers are:  9862
# the prime numbers are:  9864
# the prime numbers are:  9866
# the prime numbers are:  9868
# the prime numbers are:  9870
# the prime numbers are:  9872
# the prime numbers are:  9874
# the prime numbers are:  9876
# the prime numbers are:  9878
# the prime numbers are:  9880
# the prime numbers are:  9882
# the prime numbers are:  9884
# the prime numbers are:  9886
# the prime numbers are:  9888
# the prime numbers are:  9890
# the prime numbers are:  9892
# the prime numbers are:  9894
# the prime numbers are:  9896
# the prime numbers are:  9898
# the prime numbers are:  9900
# the prime numbers are:  9902
# the prime numbers are:  9904
# the prime numbers are:  9906
# the prime numbers are:  9908
# the prime numbers are:  9910
# the prime numbers are:  9912
# the prime numbers are:  9914
# the prime numbers are:  9916
# the prime numbers are:  9918
# the prime numbers are:  9920
# the prime numbers are:  9922
# the prime numbers are:  9924
# the prime numbers are:  9926
# the prime numbers are:  9928
# the prime numbers are:  9930
# the prime numbers are:  9932
# the prime numbers are:  9934
# the prime numbers are:  9936
# the prime numbers are:  9938
# the prime numbers are:  9940
# the prime numbers are:  9942
# the prime numbers are:  9944
# the prime numbers are:  9946
# the prime numbers are:  9948
# the prime numbers are:  9950
# the prime numbers are:  9952
# the prime numbers are:  9954
# the prime numbers are:  9956
# the prime numbers are:  9958
# the prime numbers are:  9960
# the prime numbers are:  9962
# the prime numbers are:  9964
# the prime numbers are:  9966
# the prime numbers are:  9968
# the prime numbers are:  9970
# the prime numbers are:  9972
# the prime numbers are:  9974
# the prime numbers are:  9976
# the prime numbers are:  9978
# the prime numbers are:  9980
# the prime numbers are:  9982
# the prime numbers are:  9984
# the prime numbers are:  9986
# the prime numbers are:  9988
# the prime numbers are:  9990
# the prime numbers are:  9992
# the prime numbers are:  9994
# the prime numbers are:  9996
# the prime numbers are:  9998
